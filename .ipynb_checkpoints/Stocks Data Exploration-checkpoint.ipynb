# %% [markdown]
# Source data: yfinance
# - BBCA (23/11/2020 - 23/11/2022)
# - BBNI (23/11/2020 - 23/11/2022)
# - BUMI (23/11/2020 - 23/11/2022)
# - INDY (23/11/2020 - 23/11/2022)

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
import datetime
from IPython.display import Markdown

sns.set_theme(style="whitegrid")
# plt.style.use("fivethirtyeight")

# %%
stock_list = ['bbca', 'bbni', 'bumi', 'indy', 'sido']
stock_code = ['BBCA', 'BBNI', 'BUMI', 'INDY', 'SIDO']

for a, x in zip(stock_list, stock_code):
    globals()[a] = pd.read_csv(f"C:\\Users\\LENOVO\\Stocks_exploration\\Stocks-Exploration\\{x}_23_11_2022.csv", encoding='utf-8')
    globals()[a]['Date'] = pd.to_datetime(globals()[a]['Date'])
    globals()[a]['Volume'] = globals()[a]['Volume'].astype(int)
    
bbca.head()
# Out:
#         Date    Open    High     Low   Close     Volume
# 0 2020-11-23  6600.0  6610.0  6550.0  6600.0   75265500
# 1 2020-11-24  6600.0  6600.0  6545.0  6565.0   72349500
# 2 2020-11-25  6580.0  6585.0  6380.0  6410.0  170140500
# 3 2020-11-26  6350.0  6490.0  6300.0  6480.0   64339000
# 4 2020-11-27  6480.0  6490.0  6380.0  6385.0   87361500

# %%
bbca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    489 non-null    datetime64[ns]
#  1   Open    489 non-null    float64
#  2   High    489 non-null    float64
#  3   Low     489 non-null    float64
#  4   Close   489 non-null    float64
#  5   Volume  489 non-null    int32
# dtypes: datetime64[ns](1), float64(4), int32(1)
# memory usage: 21.1 KB

# %%
chart1 = f'Open Price {stock_code[0]}, {stock_code[1]}, {stock_code[2]}, and {stock_code[3]} 2020-2022'

Markdown("""
## {title}
""".format(title=chart1))
# Out:
# ## Open Price BBCA, BBNI, BUMI, and INDY 2020-2022

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 8))
fig.tight_layout()
fig.tight_layout(pad=5)

fig.suptitle(f'{chart1}', fontweight='bold')

test = axs[0, 0].plot('Date','Open',data=bbca)
axs[0, 0].set_title(f'{stock_code[0]}')
axs[0, 0].grid(False)
axs[0, 0].set_ylabel('Open Price')
axs[0, 0].tick_params(axis='x', rotation=45)

axs[0, 1].plot('Date','Open',data=bbni)
axs[0, 1].set_title(f'{stock_code[1]}')
axs[0, 1].grid(False)
axs[0, 1].set_ylabel('Open Price')
axs[0, 1].tick_params(axis='x', rotation=45)

axs[1, 0].plot('Date','Open',data=bumi)
axs[1, 0].set_title(f'{stock_code[2]}')
axs[1, 0].grid(False)
axs[1, 0].set_ylabel('Open Price')
axs[1, 0].tick_params(axis='x', rotation=45)

axs[1, 1].plot('Date','Open',data=indy)
axs[1, 1].set_title(f'{stock_code[3]}')
axs[1, 1].grid(False)
axs[1, 1].set_ylabel('Open Price')
axs[1, 1].tick_params(axis='x', rotation=45)

plt.show()

# %%
chart2 = f'Close Price {stock_code[0]}, {stock_code[1]}, {stock_code[2]}, and {stock_code[3]} 2020-2022'

Markdown("""
## {title}
""".format(title=chart2))
# Out:
# ## Close Price BBCA, BBNI, BUMI, and INDY 2020-2022

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 8))
fig.tight_layout()
fig.tight_layout(pad=5)

fig.suptitle(f'{chart2}', fontweight='bold')

test = axs[0, 0].plot('Date','Close',data=bbca)
axs[0, 0].set_title(f'{stock_code[0]}')
axs[0, 0].grid(False)
axs[0, 0].set_ylabel('Close Price')
axs[0, 0].tick_params(axis='x', rotation=45)

axs[0, 1].plot('Date','Close',data=bbni)
axs[0, 1].set_title(f'{stock_code[1]}')
axs[0, 1].grid(False)
axs[0, 1].set_ylabel('Close Price')
axs[0, 1].tick_params(axis='x', rotation=45)

axs[1, 0].plot('Date','Close',data=bumi)
axs[1, 0].set_title(f'{stock_code[2]}')
axs[1, 0].grid(False)
axs[1, 0].set_ylabel('Close Price')
axs[1, 0].tick_params(axis='x', rotation=45)

axs[1, 1].plot('Date','Close',data=indy)
axs[1, 1].set_title(f'{stock_code[3]}')
axs[1, 1].grid(False)
axs[1, 1].set_ylabel('Close Price')
axs[1, 1].tick_params(axis='x', rotation=45)

plt.show()

# %%
chart3 = f'Volume {stock_code[0]}, {stock_code[1]}, {stock_code[2]}, and {stock_code[3]} 2020-2022'

Markdown("""
## {title}
""".format(title=chart3))
# Out:
# ## Volume BBCA, BBNI, BUMI, and INDY 2020-2022

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 8))
fig.tight_layout()
fig.tight_layout(pad=5)

fig.suptitle(f'{chart3}', fontweight='bold')

test = axs[0, 0].plot('Date','Volume',data=bbca)
axs[0, 0].set_title(f'{stock_code[0]}')
axs[0, 0].grid(False)
axs[0, 0].set_ylabel('Volume')
axs[0, 0].tick_params(axis='x', rotation=45)

axs[0, 1].plot('Date','Volume',data=bbni)
axs[0, 1].set_title(f'{stock_code[1]}')
axs[0, 1].grid(False)
axs[0, 1].set_ylabel('Volume')
axs[0, 1].tick_params(axis='x', rotation=45)

axs[1, 0].plot('Date','Volume',data=bumi)
axs[1, 0].set_title(f'{stock_code[2]}')
axs[1, 0].grid(False)
axs[1, 0].set_ylabel('Volume')
axs[1, 0].tick_params(axis='x', rotation=45)

axs[1, 1].plot('Date','Volume',data=indy)
axs[1, 1].set_title(f'{stock_code[3]}')
axs[1, 1].grid(False)
axs[1, 1].set_ylabel('Volume')
axs[1, 1].tick_params(axis='x', rotation=45)

plt.show()

# %%
chart4 = 'Distribution of Close Price 2020-2022'

Markdown("""
## {title}
""".format(title=chart4))
# Out:
# ## Distribution of Close Price 2020-2022

# %%
fig, axes = plt.subplots(2, 2, figsize=(8, 6))
fig.tight_layout()
fig.tight_layout(pad=4)

fig.suptitle(f'{chart4}', fontweight='bold')

g_bbca = sns.boxplot(x='Close', data=bbca, showmeans=True, ax=axes[0,0])
g_bbni = sns.boxplot(x='Close', data=bbni, showmeans=True, ax=axes[0,1])
g_bumi = sns.boxplot(x='Close', data=bumi, showmeans=True, ax=axes[1,0])
g_indy = sns.boxplot(x='Close', data=indy, showmeans=True, ax=axes[1,1])

g_bbca.set_title('BBCA',fontweight="normal", size=13, y=1)
g_bbca.set_xlabel('Close Price', fontsize = 12)
# g_bbca.set_ylabel('Price')

g_bbni.set_title('BBNI',fontweight="normal", size=13, y=1)
g_bbni.set_xlabel('Close Price', fontsize = 12)
# g_bbni.set_ylabel('Price')

g_bumi.set_title('BUMI',fontweight="normal", size=13, y=1)
g_bumi.set_xlabel('Close Price', fontsize = 12)
# g_bumi.set_ylabel('Price')

g_indy.set_title('INDY',fontweight="normal", size=13, y=1)
g_indy.set_xlabel('Close Price', fontsize = 12)
# g_indy.set_ylabel('Price')
    
plt.show()

# %%
chart5 = 'Average Close Price Per Month'

Markdown("""
## {title}
""".format(title=chart5))
# Out:
# ## Average Close Price Per Month

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
fig.tight_layout()
fig.tight_layout(pad=4)

# test = 'sample'
var = ['bbca_sample', 'bbca_sample', 'bbca_sample']

for x in stock_list:
    str(x+'teds') = 1
    print(x+'teds')
#      str([x] + '_sample') =  globals()[x].resample('M', on='Date').mean()
#     print([x])

# bbca_sample = bbca.resample('M', on='Date').mean()
# bbni_sample = bbni.resample('M', on='Date').mean()
# bumi_sample = bumi.resample('M', on='Date').mean()
# indy_sample = indy.resample('M', on='Date').mean()

fig.suptitle(f'{chart5}', fontweight='bold')

g_bbca = sns.boxplot(y="Open",x=bbca_sample.index.month, data=bbca_sample, showmeans=True, ax=axes[0,0])
g_bbni = sns.boxplot(y="Open",x=bbni_sample.index.month, data=bbni_sample, showmeans=True, ax=axes[0,1])
g_bumi = sns.boxplot(y="Open",x=bumi_sample.index.month, data=bumi_sample, showmeans=True, ax=axes[1,0])
g_indy = sns.boxplot(y="Open",x=indy_sample.index.month, data=indy_sample, showmeans=True, ax=axes[1,1])

g_bbca.set_title('BBCA',fontweight="normal", size=13, y=1)
g_bbca.set_xlabel('Month', fontsize = 12)
g_bbca.set_ylabel('Volume')

g_bbni.set_title('BBNI',fontweight="normal", size=13, y=1)
g_bbni.set_xlabel('Month', fontsize = 12)
g_bbni.set_ylabel('Volume')

g_bumi.set_title('BUMI',fontweight="normal", size=13, y=1)
g_bumi.set_xlabel('Month', fontsize = 12)
g_bumi.set_ylabel('Volume')

g_indy.set_title('INDY',fontweight="normal", size=13, y=1)
g_indy.set_xlabel('Month', fontsize = 12)
g_indy.set_ylabel('Volume')
    
plt.show()
# Out:
#   Input In [35]
#     str(x+'teds') = 1
#     ^
# SyntaxError: cannot assign to function call

# %%
# chart5 = 'Average Volume Per Month'

# Markdown("""
# ## {title}
# """.format(title=chart5))

# %%
for i in stock_list:
    globals()[i]_sample["Bulan"] = globals()[i]_sample.index.month
    globals()[i]_sample["Tahun"] = globals()[i]_sample.index.year
    globals()[i]_pivot = globals()[i]_sample.pivot("Bulan", "Tahun", "Close")

# bbca_sample["Bulan"] = bbca_sample.index.month
# bbca_sample["Tahun"] = bbca_sample.index.year

# bbni_sample["Bulan"] = bbni_sample.index.month
# bbni_sample["Tahun"] = bbni_sample.index.year

# bumi_sample["Bulan"] = bumi_sample.index.month
# bumi_sample["Tahun"] = bumi_sample.index.year

# indy_sample["Bulan"] = indy_sample.index.month
# indy_sample["Tahun"] = indy_sample.index.year

# bbca_pivot = bbca_sample.pivot("Bulan", "Tahun", "Close")
# bbni_pivot = bbni_sample.pivot("Bulan", "Tahun", "Close")
# bumi_pivot = bumi_sample.pivot("Bulan", "Tahun", "Close")
# indy_pivot = indy_sample.pivot("Bulan", "Tahun", "Close")
# Out:
#   Input In [17]
#     globals()[i]_sample["Bulan"] = globals()[i]_sample.index.month
#                 ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(8,6))
g = sns.heatmap(data=bbca_pivot, annot=True, fmt=".0f")
x = sns.heatmap(data=bbni_pivot, annot=True, fmt=".0f")

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5.8))
fig.tight_layout()
fig.tight_layout(pad=5)

plt.suptitle(f'Jumlah Dosen Berdasarkan Gender dan Pendidikan Terakhir', fontsize = 'x-large', fontweight = 'normal', y=1)

gender = sns.histplot(x='Open', data = bbca, color="blue", bins=30, ax=axes[0])
pend = sns.histplot(x='Open', data = bbni, color="red", ax=axes[1])
# sns.displot(df, x="Usia", hue="Pendidikan Terakhir", kind="kde", fill=True)

# gender.set_title('Berdasarkan Gender',fontweight="normal", size=13, y=1.05)
# gender.set_xlabel('Gender', fontsize = 12)
# gender.set_ylabel('Jumlah Dosen')


# pend.set_title('Berdasarkan Pendidikan Terakhir',fontweight="normal", size=13, y=1.05)
# pend.set_xlabel('Pendidikan Terakhir', fontsize = 12)
# pend.set_ylabel('Jumlah Dosen')


# tampilkan value 
# for container in gender.containers:
#     gender.bar_label(container, padding=3)
    
# for container in pend.containers:
#     pend.bar_label(container, padding=3)
    
# plt.show()

# %%
# plt.figure(figsize=(18,4))
# g = sns.lineplot(data=bbca,x="Date", y="Close")
# g.set_xticklabe(rotation=45)

plt.figure(figsize=(10,4))
plt.plot('Date','Close',data=bbca)
plt.grid(False)
plt.title('BBCA Close')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot('Date','Open',data=bbca)
plt.grid(False)
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot('Date','Volume',data=bumi)
plt.grid(False)
plt.title('BBCA Close')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.xticks(rotation=45)

plt.show()

# %%
# bbca = bbca.resample('M', on='Date').median()
# bbca.tail()

# %%
# plt.rc('figure',figsize=(12,8)) #ukuran chart
# plt.rc('font',size=15)
# result = seasonal_decompose(bbca.Close,model='additive',period=60)
# fig = result.plot()

# %%
# stocks_list = [BBCA, BBNI, BUMI, INDY]

# %%
# plt.figure(figsize=(15, 6))
# plt.subplots_adjust(top=1.25, bottom=1.2)

# for i, company in enumerate(, 1):
#     plt.subplot(2, 2, i)
#     company['Open'].plot()
#     plt.ylabel('Open')
#     plt.xlabel(None)
#     plt.title(f"Open Price of {tech_list[i - 1]}")
    
# plt.tight_layout()

# %%
# file_list=['BBCA_23_11_2022.csv','BBNI_23_11_2022.csv']
  
# main_dataframe = pd.DataFrame(pd.read_csv(file_list[0]))
  
# for i in range(1,len(file_list)):
#     data = pd.read_csv(file_list[i])
#     df = pd.DataFrame(data)
#     main_dataframe = pd.concat([main_dataframe,df],axis=1)
# # print(main_dataframe)

# df.head()

# %%
# import pandas as pd
# import numpy as np

# import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set_style('whitegrid')
# plt.style.use("fivethirtyeight")
# %matplotlib inline

# # For reading stock data from yahoo
# from pandas_datareader.data import DataReader
# import yfinance as yf

# # For time stamps
# from datetime import datetime

# %%
# # The tech stocks we'll use for this analysis
# tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']

# # Set up End and Start times for data grab
# tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']

# end = datetime.now()
# start = datetime(end.year - 1, end.month, end.day)

# for stock in tech_list:
#     globals()[stock] = yf.download(stock, start, end)

# %%
# company_list = [AAPL, GOOG, MSFT, AMZN]
# company_name = ["APPLE", "GOOGLE", "MICROSOFT", "AMAZON"]

# for company, com_name in zip(company_list, company_name):
#     company["company_name"] = com_name
    
# df = pd.concat(company_list, axis=0)
# df.tail(10)

# %%
# company_list

# %%
# plt.figure(figsize=(15, 6))
# plt.subplots_adjust(top=1.25, bottom=1.2)

# for i, company in enumerate(company_list, 1):
#     plt.subplot(2, 2, i)
#     company['Adj Close'].plot()
#     plt.ylabel('Adj Close')
#     plt.xlabel(None)
#     plt.title(f"Closing Price of {tech_list[i - 1]}")
    
# plt.tight_layout()
